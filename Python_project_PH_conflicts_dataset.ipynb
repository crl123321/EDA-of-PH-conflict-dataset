# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pr = pd.read_csv('conflict_data_phl.csv')
pr.head()
# Out:
#          id              relid        year  active_year code_status  \
# 0       NaN                NaN  #date+year          NaN         NaN
# 1  123403.0  PHI-1989-1-217-51        1989          1.0       Clear
# 2  124029.0   PHI-1989-1-217-1        1989          1.0       Clear
# 3  125199.0   PHI-1989-1-217-2        1989          1.0       Clear
# 4  123871.0   PHI-1989-1-217-5        1989          1.0       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 0               NaN               NaN              NaN
# 1               1.0             209.0            209.0
# 2               1.0             209.0            209.0
# 3               1.0             209.0            209.0
# 4               1.0             209.0            209.0
#
#              conflict_name  dyad_dset_id  ...                 date_end  \
# 0                      NaN           NaN  ...                #date+end
# 1  Philippines: Government         411.0  ...  1989-07-03 00:00:00.000
# ...

# %%
pr.info()
pr.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4036 entries, 0 to 4035
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4035 non-null   float64
#  1   relid              4035 non-null   object
#  2   year               4036 non-null   object
#  3   active_year        4035 non-null   float64
#  4   code_status        4035 non-null   object
#  5   type_of_violence   4035 non-null   float64
#  6   conflict_dset_id   4035 non-null   float64
#  7   conflict_new_id    4035 non-null   float64
#  8   conflict_name      4035 non-null   object
#  9   dyad_dset_id       4035 non-null   float64
#  10  dyad_new_id        4035 non-null   float64
#  11  dyad_name          4035 non-null   object
#  12  side_a_dset_id     4035 non-null   float64
#  13  side_a_new_id      4035 non-null   float64
#  14  side_a             4036 non-null   object
# ...

# %%
pr.describe(exclude='number')
# Out:
#                     relid  year code_status            conflict_name  \
# count                4035  4036        4035                     4035
# unique               4035    34           1                       17
# top     PHI-1989-1-217-51  2017       Clear  Philippines: Government
# freq                    1   265        4035                     1924
#
#                               dyad_name                     side_a side_b  \
# count                              4035                       4036   4036
# unique                               26                         15     20
# top     Government of Philippines - CPP  Government of Philippines    CPP
# freq                               1917                       3606   1917
#
#        source_article                  source_office source_date  ...  \
# count            4036                           1450        1450  ...
# unique           3504                            180        1169  ...
# ...

# %%
pr.drop(pr.index[0], inplace=True)
pr.head()
# Out:
#          id              relid  year  active_year code_status  \
# 1  123403.0  PHI-1989-1-217-51  1989          1.0       Clear
# 2  124029.0   PHI-1989-1-217-1  1989          1.0       Clear
# 3  125199.0   PHI-1989-1-217-2  1989          1.0       Clear
# 4  123871.0   PHI-1989-1-217-5  1989          1.0       Clear
# 5  123430.0   PHI-1989-1-217-4  1989          1.0       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 1               1.0             209.0            209.0
# 2               1.0             209.0            209.0
# 3               1.0             209.0            209.0
# 4               1.0             209.0            209.0
# 5               1.0             209.0            209.0
#
#              conflict_name  dyad_dset_id  ...                 date_end  \
# 1  Philippines: Government         411.0  ...  1989-07-03 00:00:00.000
# 2  Philippines: Government         411.0  ...  1989-01-15 00:00:00.000
# ...

# %%
years = pr.groupby('year').count()['id'].reset_index() 
years
# Out:
#     year   id
# 0   1989  135
# 1   1990  126
# 2   1991  113
# 3   1992   59
# 4   1993   45
# 5   1994   40
# 6   1995   18
# 7   1996   26
# 8   1997   40
# 9   1998   23
# 10  1999   48
# 11  2000  171
# 12  2001  146
# 13  2002  211
# 14  2003  151
# 15  2004  135
# 16  2005  124
# 17  2006  131
# 18  2007  103
# 19  2008  182
# 20  2009  155
# 21  2010  119
# 22  2011  149
# 23  2012  109
# 24  2013  139
# 25  2014  149
# 26  2015  203
# 27  2016  168
# 28  2017  265
# 29  2018  123
# 30  2019  130
# 31  2020  157
# 32  2021  142

# %%
fig = plt.figure(figsize = (25,10))
sns.lineplot(x = "year", y = "id", data = years, marker = "o")
plt.title("Number of Cinflicts per Year")
plt.xlabel("")
plt.ylabel("")
plt.style.use("fivethirtyeight")
plt.show()

# %%
most = years.sort_values(by = "id", ascending = False)
most
# Out:
#     year   id
# 28  2017  265
# 13  2002  211
# 26  2015  203
# 19  2008  182
# 11  2000  171
# 27  2016  168
# 31  2020  157
# 20  2009  155
# 14  2003  151
# 25  2014  149
# 22  2011  149
# 12  2001  146
# 32  2021  142
# 24  2013  139
# 15  2004  135
# 0   1989  135
# 17  2006  131
# 30  2019  130
# 1   1990  126
# 16  2005  124
# 29  2018  123
# 21  2010  119
# 2   1991  113
# 23  2012  109
# 18  2007  103
# 3   1992   59
# 10  1999   48
# 4   1993   45
# 8   1997   40
# 5   1994   40
# 7   1996   26
# 9   1998   23
# 6   1995   18

# %%
year = most["year"]
id = most["id"]

fig = plt.figure(figsize = (25,10))
plt.barh(year[::-1], id[::-1])
plt.title("Number of Conflicts from 1989 to 2021", loc = "center")

plt.show()

# %%
pr['adm_1'].unique()
# Out:
# array(['Metropolitan Manila province', 'Cotabato province',
#        'Maguindanao province', 'Surigao del Sur province',
#        'Aurora province', 'Bohol province', 'Agusan del Sur province',
#        nan, 'Lanao del Norte province', 'Samar province', 'Abra province',
#        'Davao Oriental province', 'Misamis Oriental province',
#        'Zamboanga del Sur province', 'Ifugao province', 'Bataan province',
#        'Negros Occidental province', 'Surigao del Norte province',
#        'Zamboanga del Norte province', 'Camarines Sur province',
#        'Davao del Sur province', 'Isabela province', 'Leyte province',
#        'Bulacan province', 'Sorsogon province', 'Iloilo province',
#        'Pampanga province', 'Ilocos Norte province', 'Rizal province',
#        'Kalinga-Apayao province', 'Quezon province', 'Kalinga province',
#        'Camarines Norte province', 'Benguet province',
#        'Pangasinan province', 'Davao province',
# ...

# %%
pr['adm_2'].unique()
# Out:
# array(['Manila City municipality', 'Makilala municipality',
#        'Sultan Kudarat municipality', nan, 'Lupon municipality',
#        'Lakewood municipality', 'Candoni municipality',
#        'Dipolog City municipality', 'Burauen municipality',
#        'Paombong municipality', 'Leon municipality',
#        'Mabalacat municipality', 'Malabon municipality',
#        'Taytay municipality', 'Pudtol municipality', 'Tabuk municipality',
#        'Cainta municipality', 'Digos City municipality',
#        'Valenzuela municipality', 'Pasay City municipality',
#        'Tago municipality', 'Lopez municipality',
#        'Bago City municipality', 'Porac municipality',
#        'San Francisco municipality', 'Monkayo municipality',
#        'Bongabong municipality', 'Basey municipality',
#        'Nabas municipality', 'Tuao municipality',
#        'Pasig City municipality', 'Las Pinas municipality',
#        'Atimonan municipality', 'Mexico municipality',
# ...

# %%
province = pr.groupby('adm_1').count()['id'].reset_index().sort_values(by = 'id', ascending=False)
province
# Out:
#                        adm_1   id
# 68             Sulu province  393
# 43      Maguindanao province  352
# 8           Basilan province  329
# 25         Cotabato province  223
# 41    Lanao del Sur province  181
# ..                       ...  ...
# 53    Nueva Viscaya province    2
# 6            Apayao province    2
# 30  Dinagat islands province    1
# 54    Nueva Vizcaya province    1
# 12          Biliran province    1
#
# [77 rows x 2 columns]

# %%
adm = province['adm_1']
ids = province['id']

fig = plt.figure(figsize = (25,25))
plt.barh(adm[::-1], ids[::-1])
plt.title("Number of Conflicts per Province", loc = "center")

plt.show()

# %%
mun = pr.groupby(['year', 'adm_2']).count()['id'].reset_index().sort_values(by = 'id', ascending=False).head(10)
mun
# Out:
#       year                        adm_2   id
# 1692  2017     Marawi City municipality  104
# 1337  2013  Zamboanga City municipality   27
# 30    1989     Manila City municipality   20
# 1588  2016     Manila City municipality   17
# 1603  2016         Patikul municipality   15
# 1508  2015         Patikul municipality   14
# 1782  2018         Patikul municipality   13
# 1945  2020         Patikul municipality   11
# 83    1990     Manila City municipality   11
# 1859  2019         Patikul municipality   11

# %%
pivot1 = mun.pivot('adm_2', 'year', 'id').head(10)
pivot1
# Out:
# year                         1989  1990  2013  2015  2016   2017  2018  2019  \
# adm_2
# Manila City municipality     20.0  11.0   NaN   NaN  17.0    NaN   NaN   NaN
# Marawi City municipality      NaN   NaN   NaN   NaN   NaN  104.0   NaN   NaN
# Patikul municipality          NaN   NaN   NaN  14.0  15.0    NaN  13.0  11.0
# Zamboanga City municipality   NaN   NaN  27.0   NaN   NaN    NaN   NaN   NaN
#
# year                         2020
# adm_2
# Manila City municipality      NaN
# Marawi City municipality      NaN
# Patikul municipality         11.0
# Zamboanga City municipality   NaN

# %%
mun2 = pr.groupby('adm_2').count()['id'].reset_index().sort_values(by = 'id', ascending=False).head(10)
mun2
# Out:
#                            adm_2   id
# 480         Patikul municipality  138
# 382     Marawi City municipality  108
# 168      Davao City municipality   83
# 684  Zamboanga City municipality   70
# 372     Manila City municipality   68
# 609         Sumisip municipality   60
# 234         Indanan municipality   57
# 164      Datu Piang municipality   42
# 578   Shariff Aguak municipality   31
# 135          Carmen municipality   31

# %%
adm2 = mun2['adm_2']
idss = mun2['id']

fig = plt.figure(figsize = (25,25))
plt.barh(adm2[::-1], idss[::-1])
plt.title("Number of Conflicts per Municipality", loc = "center")

plt.show()
